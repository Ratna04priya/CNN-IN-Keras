# %% [markdown]
# # Artificial Intelligence Nanodegree
# ## Convolutional Neural Networks

# %% [markdown]
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.

# %% [markdown]
# ## 1. Load CIFAR-10 DATABASE

# %%
import keras
from keras.datasets import cifar10
(x_train,y_train),(x_test,y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 9s 0us/step

# %% [markdown]
# ## 2.Visualize the First 36 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ## 3. Rescale the imaging

# %%
# rescaling the image 
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ## 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one - hot encoding
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ## 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0803 13:44:42.709947 140696570042240 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0803 13:44:42.747049 140696570042240 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0803 13:44:42.755225 140696570042240 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0803 13:44:42.782254 140696570042240 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0803 13:44:42.816395 140696570042240 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0803 13:44:42.826279 140696570042240 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 6. Compile the Model

# %%
# Compile the resulting model
model.compile(loss ='categorical_crossentropy', optimizer='rmsprop',  metrics=['accuracy'])
# Out:
# W0803 13:44:47.567199 140696570042240 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0803 13:44:47.592715 140696570042240 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.

# %% [markdown]
# ## 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# W0803 13:44:51.196894 140696570042240 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 13s - loss: 1.5792 - acc: 0.4276 - val_loss: 1.3229 - val_acc: 0.5338
#
# Epoch 00001: val_loss improved from inf to 1.32293, saving model to model.weights.best.hdf5
# Epoch 2/100
#  - 6s - loss: 1.2745 - acc: 0.5442 - val_loss: 1.2619 - val_acc: 0.5402
#
# Epoch 00002: val_loss improved from 1.32293 to 1.26189, saving model to model.weights.best.hdf5
# Epoch 3/100
#  - 6s - loss: 1.1626 - acc: 0.5874 - val_loss: 1.1394 - val_acc: 0.5982
#
# Epoch 00003: val_loss improved from 1.26189 to 1.13944, saving model to model.weights.best.hdf5
# Epoch 4/100
#  - 6s - loss: 1.0985 - acc: 0.6134 - val_loss: 0.9684 - val_acc: 0.6614
#
# Epoch 00004: val_loss improved from 1.13944 to 0.96843, saving model to model.weights.best.hdf5
# Epoch 5/100
#  - 6s - loss: 1.0520 - acc: 0.6320 - val_loss: 1.0148 - val_acc: 0.6382
#
# Epoch 00005: val_loss did not improve from 0.96843
# Epoch 6/100
#  - 6s - loss: 1.0258 - acc: 0.6452 - val_loss: 1.0202 - val_acc: 0.6566
#
# Epoch 00006: val_loss did not improve from 0.96843
# Epoch 7/100
#  - 6s - loss: 1.0110 - acc: 0.6526 - val_loss: 1.1635 - val_acc: 0.6376
#
# Epoch 00007: val_loss did not improve from 0.96843
# Epoch 8/100
#  - 6s - loss: 1.0030 - acc: 0.6556 - val_loss: 1.0801 - val_acc: 0.6306
#
# Epoch 00008: val_loss did not improve from 0.96843
# Epoch 9/100
#  - 6s - loss: 1.0103 - acc: 0.6573 - val_loss: 0.9234 - val_acc: 0.6872
#
# Epoch 00009: val_loss improved from 0.96843 to 0.92340, saving model to model.weights.best.hdf5
# Epoch 10/100
#  - 6s - loss: 1.0187 - acc: 0.6548 - val_loss: 1.0318 - val_acc: 0.6568
#
# Epoch 00010: val_loss did not improve from 0.92340
# Epoch 11/100
#  - 6s - loss: 1.0189 - acc: 0.6536 - val_loss: 0.9676 - val_acc: 0.6904
#
# Epoch 00011: val_loss did not improve from 0.92340
# Epoch 12/100
#  - 6s - loss: 1.0230 - acc: 0.6585 - val_loss: 1.1267 - val_acc: 0.6624
#
# Epoch 00012: val_loss did not improve from 0.92340
# Epoch 13/100
#  - 6s - loss: 1.0341 - acc: 0.6528 - val_loss: 0.9910 - val_acc: 0.6924
#
# Epoch 00013: val_loss did not improve from 0.92340
# Epoch 14/100
#  - 6s - loss: 1.0517 - acc: 0.6479 - val_loss: 1.1256 - val_acc: 0.6228
#
# Epoch 00014: val_loss did not improve from 0.92340
# Epoch 15/100
#  - 6s - loss: 1.0661 - acc: 0.6461 - val_loss: 1.0175 - val_acc: 0.6652
#
# Epoch 00015: val_loss did not improve from 0.92340
# Epoch 16/100
#  - 6s - loss: 1.0879 - acc: 0.6394 - val_loss: 0.9618 - val_acc: 0.6714
#
# Epoch 00016: val_loss did not improve from 0.92340
# Epoch 17/100
#  - 6s - loss: 1.1136 - acc: 0.6307 - val_loss: 0.9763 - val_acc: 0.6822
#
# Epoch 00017: val_loss did not improve from 0.92340
# Epoch 18/100
#  - 6s - loss: 1.1366 - acc: 0.6260 - val_loss: 1.4173 - val_acc: 0.5620
#
# Epoch 00018: val_loss did not improve from 0.92340
# Epoch 19/100
#  - 6s - loss: 1.1527 - acc: 0.6229 - val_loss: 1.1705 - val_acc: 0.6458
#
# Epoch 00019: val_loss did not improve from 0.92340
# Epoch 20/100
#  - 6s - loss: 1.1715 - acc: 0.6157 - val_loss: 1.4748 - val_acc: 0.5488
#
# Epoch 00020: val_loss did not improve from 0.92340
# Epoch 21/100
#  - 6s - loss: 1.1770 - acc: 0.6128 - val_loss: 1.9520 - val_acc: 0.5744
#
# Epoch 00021: val_loss did not improve from 0.92340
# Epoch 22/100
#  - 6s - loss: 1.2008 - acc: 0.6058 - val_loss: 1.1089 - val_acc: 0.6328
#
# Epoch 00022: val_loss did not improve from 0.92340
# Epoch 23/100
#  - 6s - loss: 1.2322 - acc: 0.5967 - val_loss: 2.3707 - val_acc: 0.5320
#
# Epoch 00023: val_loss did not improve from 0.92340
# Epoch 24/100
#  - 6s - loss: 1.2303 - acc: 0.5970 - val_loss: 1.2004 - val_acc: 0.5870
#
# Epoch 00024: val_loss did not improve from 0.92340
# Epoch 25/100
#  - 6s - loss: 1.2457 - acc: 0.5888 - val_loss: 1.5535 - val_acc: 0.6124
#
# Epoch 00025: val_loss did not improve from 0.92340
# Epoch 26/100
#  - 7s - loss: 1.2682 - acc: 0.5820 - val_loss: 1.1012 - val_acc: 0.6402
#
# Epoch 00026: val_loss did not improve from 0.92340
# Epoch 27/100
#  - 6s - loss: 1.2881 - acc: 0.5782 - val_loss: 1.3363 - val_acc: 0.6014
#
# Epoch 00027: val_loss did not improve from 0.92340
# Epoch 28/100
#  - 6s - loss: 1.3015 - acc: 0.5714 - val_loss: 1.1874 - val_acc: 0.6322
#
# Epoch 00028: val_loss did not improve from 0.92340
# Epoch 29/100
#  - 6s - loss: 1.3112 - acc: 0.5671 - val_loss: 1.2089 - val_acc: 0.5928
#
# Epoch 00029: val_loss did not improve from 0.92340
# Epoch 30/100
#  - 6s - loss: 1.3351 - acc: 0.5611 - val_loss: 1.3017 - val_acc: 0.5544
#
# Epoch 00030: val_loss did not improve from 0.92340
# Epoch 31/100
#  - 6s - loss: 1.3379 - acc: 0.5578 - val_loss: 1.8851 - val_acc: 0.5098
#
# Epoch 00031: val_loss did not improve from 0.92340
# Epoch 32/100
#  - 6s - loss: 1.3572 - acc: 0.5554 - val_loss: 3.4663 - val_acc: 0.5524
#
# Epoch 00032: val_loss did not improve from 0.92340
# Epoch 33/100
#  - 7s - loss: 1.3863 - acc: 0.5449 - val_loss: 1.1590 - val_acc: 0.6016
#
# Epoch 00033: val_loss did not improve from 0.92340
# Epoch 34/100
#  - 7s - loss: 1.4089 - acc: 0.5336 - val_loss: 1.1732 - val_acc: 0.6046
#
# Epoch 00034: val_loss did not improve from 0.92340
# Epoch 35/100
#  - 6s - loss: 1.4364 - acc: 0.5232 - val_loss: 1.6507 - val_acc: 0.4292
#
# Epoch 00035: val_loss did not improve from 0.92340
# Epoch 36/100
#  - 6s - loss: 1.4512 - acc: 0.5178 - val_loss: 1.3473 - val_acc: 0.5402
#
# Epoch 00036: val_loss did not improve from 0.92340
# Epoch 37/100
#  - 6s - loss: 1.4544 - acc: 0.5170 - val_loss: 1.4245 - val_acc: 0.4814
#
# Epoch 00037: val_loss did not improve from 0.92340
# Epoch 38/100
#  - 6s - loss: 1.4698 - acc: 0.5117 - val_loss: 1.5626 - val_acc: 0.5428
#
# Epoch 00038: val_loss did not improve from 0.92340
# Epoch 39/100
#  - 6s - loss: 1.4863 - acc: 0.5063 - val_loss: 1.8776 - val_acc: 0.5080
#
# Epoch 00039: val_loss did not improve from 0.92340
# Epoch 40/100
#  - 6s - loss: 1.5061 - acc: 0.4948 - val_loss: 1.3510 - val_acc: 0.5502
#
# Epoch 00040: val_loss did not improve from 0.92340
# Epoch 41/100
#  - 6s - loss: 1.4840 - acc: 0.5018 - val_loss: 1.6209 - val_acc: 0.4990
#
# Epoch 00041: val_loss did not improve from 0.92340
# Epoch 42/100
#  - 6s - loss: 1.4984 - acc: 0.4972 - val_loss: 2.1612 - val_acc: 0.4716
#
# Epoch 00042: val_loss did not improve from 0.92340
# Epoch 43/100
#  - 6s - loss: 1.5063 - acc: 0.4926 - val_loss: 1.4100 - val_acc: 0.5062
#
# Epoch 00043: val_loss did not improve from 0.92340
# Epoch 44/100
#  - 6s - loss: 1.5159 - acc: 0.4931 - val_loss: 1.7837 - val_acc: 0.5262
#
# Epoch 00044: val_loss did not improve from 0.92340
# Epoch 45/100
#  - 6s - loss: 1.5176 - acc: 0.4899 - val_loss: 1.4659 - val_acc: 0.5018
#
# Epoch 00045: val_loss did not improve from 0.92340
# Epoch 46/100
#  - 6s - loss: 1.5402 - acc: 0.4874 - val_loss: 1.7165 - val_acc: 0.4384
#
# Epoch 00046: val_loss did not improve from 0.92340
# Epoch 47/100
#  - 6s - loss: 1.5434 - acc: 0.4834 - val_loss: 1.3144 - val_acc: 0.5442
#
# Epoch 00047: val_loss did not improve from 0.92340
# Epoch 48/100
#  - 6s - loss: 1.5540 - acc: 0.4794 - val_loss: 1.3022 - val_acc: 0.5382
#
# Epoch 00048: val_loss did not improve from 0.92340
# Epoch 49/100
#  - 6s - loss: 1.5707 - acc: 0.4699 - val_loss: 1.3474 - val_acc: 0.5248
#
# Epoch 00049: val_loss did not improve from 0.92340
# Epoch 50/100
#  - 6s - loss: 1.5429 - acc: 0.4799 - val_loss: 1.3594 - val_acc: 0.5412
#
# Epoch 00050: val_loss did not improve from 0.92340
# Epoch 51/100
#  - 6s - loss: 1.5749 - acc: 0.4732 - val_loss: 2.4872 - val_acc: 0.4488
#
# Epoch 00051: val_loss did not improve from 0.92340
# Epoch 52/100
#  - 6s - loss: 1.5830 - acc: 0.4690 - val_loss: 1.2315 - val_acc: 0.5824
#
# Epoch 00052: val_loss did not improve from 0.92340
# Epoch 53/100
#  - 6s - loss: 1.6031 - acc: 0.4611 - val_loss: 1.5825 - val_acc: 0.4526
#
# Epoch 00053: val_loss did not improve from 0.92340
# Epoch 54/100
#  - 7s - loss: 1.6239 - acc: 0.4498 - val_loss: 1.5710 - val_acc: 0.4292
#
# Epoch 00054: val_loss did not improve from 0.92340
# Epoch 55/100
#  - 7s - loss: 1.6360 - acc: 0.4426 - val_loss: 1.7646 - val_acc: 0.4514
#
# Epoch 00055: val_loss did not improve from 0.92340
# Epoch 56/100
#  - 6s - loss: 1.6505 - acc: 0.4427 - val_loss: 1.6114 - val_acc: 0.4564
#
# Epoch 00056: val_loss did not improve from 0.92340
# Epoch 57/100
#  - 6s - loss: 1.6533 - acc: 0.4358 - val_loss: 1.4505 - val_acc: 0.5034
#
# Epoch 00057: val_loss did not improve from 0.92340
# Epoch 58/100
#  - 6s - loss: 1.6680 - acc: 0.4284 - val_loss: 1.5843 - val_acc: 0.5016
#
# Epoch 00058: val_loss did not improve from 0.92340
# Epoch 59/100
#  - 6s - loss: 1.6756 - acc: 0.4349 - val_loss: 2.2947 - val_acc: 0.4262
#
# Epoch 00059: val_loss did not improve from 0.92340
# Epoch 60/100
#  - 6s - loss: 1.6915 - acc: 0.4242 - val_loss: 1.3693 - val_acc: 0.5208
#
# Epoch 00060: val_loss did not improve from 0.92340
# Epoch 61/100
#  - 6s - loss: 1.6980 - acc: 0.4212 - val_loss: 1.5874 - val_acc: 0.4958
#
# Epoch 00061: val_loss did not improve from 0.92340
# Epoch 62/100
#  - 6s - loss: 1.7146 - acc: 0.4122 - val_loss: 2.1009 - val_acc: 0.3452
#
# Epoch 00062: val_loss did not improve from 0.92340
# Epoch 63/100
#  - 6s - loss: 1.7287 - acc: 0.4059 - val_loss: 2.1086 - val_acc: 0.3926
#
# Epoch 00063: val_loss did not improve from 0.92340
# Epoch 64/100
#  - 6s - loss: 1.7316 - acc: 0.4026 - val_loss: 1.4861 - val_acc: 0.4828
#
# Epoch 00064: val_loss did not improve from 0.92340
# Epoch 65/100
#  - 6s - loss: 1.7363 - acc: 0.4034 - val_loss: 1.5923 - val_acc: 0.4330
#
# Epoch 00065: val_loss did not improve from 0.92340
# Epoch 66/100
#  - 6s - loss: 1.7640 - acc: 0.4007 - val_loss: 1.6514 - val_acc: 0.3998
#
# Epoch 00066: val_loss did not improve from 0.92340
# Epoch 67/100
#  - 6s - loss: 1.7782 - acc: 0.3874 - val_loss: 1.6842 - val_acc: 0.4242
#
# Epoch 00067: val_loss did not improve from 0.92340
# Epoch 68/100
#  - 6s - loss: 1.7567 - acc: 0.3922 - val_loss: 1.6265 - val_acc: 0.4336
#
# Epoch 00068: val_loss did not improve from 0.92340
# Epoch 69/100
#  - 6s - loss: 1.7593 - acc: 0.3921 - val_loss: 1.5590 - val_acc: 0.4636
#
# Epoch 00069: val_loss did not improve from 0.92340
# Epoch 70/100
#  - 6s - loss: 1.7686 - acc: 0.3904 - val_loss: 1.7913 - val_acc: 0.3402
#
# Epoch 00070: val_loss did not improve from 0.92340
# Epoch 71/100
#  - 6s - loss: 1.7753 - acc: 0.3799 - val_loss: 1.6335 - val_acc: 0.4466
#
# Epoch 00071: val_loss did not improve from 0.92340
# Epoch 72/100
#  - 6s - loss: 1.7875 - acc: 0.3814 - val_loss: 2.4125 - val_acc: 0.3186
#
# Epoch 00072: val_loss did not improve from 0.92340
# Epoch 73/100
#  - 6s - loss: 1.7932 - acc: 0.3750 - val_loss: 1.6031 - val_acc: 0.4466
#
# Epoch 00073: val_loss did not improve from 0.92340
# Epoch 74/100
#  - 6s - loss: 1.7932 - acc: 0.3748 - val_loss: 1.9045 - val_acc: 0.3216
#
# Epoch 00074: val_loss did not improve from 0.92340
# Epoch 75/100
#  - 6s - loss: 1.8000 - acc: 0.3702 - val_loss: 1.7194 - val_acc: 0.3986
#
# Epoch 00075: val_loss did not improve from 0.92340
# Epoch 76/100
#  - 6s - loss: 1.8091 - acc: 0.3668 - val_loss: 1.8688 - val_acc: 0.2838
#
# Epoch 00076: val_loss did not improve from 0.92340
# Epoch 77/100
#  - 6s - loss: 1.8141 - acc: 0.3657 - val_loss: 1.8242 - val_acc: 0.3240
#
# Epoch 00077: val_loss did not improve from 0.92340
# Epoch 78/100
#  - 6s - loss: 1.8070 - acc: 0.3637 - val_loss: 1.6782 - val_acc: 0.4344
#
# Epoch 00078: val_loss did not improve from 0.92340
# Epoch 79/100
#  - 6s - loss: 1.8315 - acc: 0.3523 - val_loss: 3.5891 - val_acc: 0.3298
#
# Epoch 00079: val_loss did not improve from 0.92340
# Epoch 80/100
#  - 6s - loss: 1.8322 - acc: 0.3560 - val_loss: 1.8228 - val_acc: 0.3370
#
# Epoch 00080: val_loss did not improve from 0.92340
# Epoch 81/100
#  - 6s - loss: 1.8054 - acc: 0.3573 - val_loss: 1.4760 - val_acc: 0.4690
#
# Epoch 00081: val_loss did not improve from 0.92340
# Epoch 82/100
#  - 6s - loss: 1.8173 - acc: 0.3558 - val_loss: 1.6944 - val_acc: 0.3962
#
# Epoch 00082: val_loss did not improve from 0.92340
# Epoch 83/100
#  - 7s - loss: 1.8083 - acc: 0.3540 - val_loss: 1.6264 - val_acc: 0.4158
#
# Epoch 00083: val_loss did not improve from 0.92340
# Epoch 84/100
#  - 6s - loss: 1.8447 - acc: 0.3472 - val_loss: 1.9311 - val_acc: 0.3276
#
# Epoch 00084: val_loss did not improve from 0.92340
# Epoch 85/100
#  - 6s - loss: 1.8234 - acc: 0.3506 - val_loss: 1.5647 - val_acc: 0.4378
#
# Epoch 00085: val_loss did not improve from 0.92340
# Epoch 86/100
#  - 6s - loss: 1.8130 - acc: 0.3479 - val_loss: 3.3732 - val_acc: 0.3216
#
# Epoch 00086: val_loss did not improve from 0.92340
# Epoch 87/100
#  - 6s - loss: 1.8279 - acc: 0.3433 - val_loss: 2.3329 - val_acc: 0.2272
#
# Epoch 00087: val_loss did not improve from 0.92340
# Epoch 88/100
#  - 6s - loss: 1.8373 - acc: 0.3483 - val_loss: 1.7419 - val_acc: 0.3194
#
# Epoch 00088: val_loss did not improve from 0.92340
# Epoch 89/100
#  - 6s - loss: 1.8244 - acc: 0.3465 - val_loss: 1.8163 - val_acc: 0.3710
#
# Epoch 00089: val_loss did not improve from 0.92340
# Epoch 90/100
#  - 6s - loss: 1.8264 - acc: 0.3429 - val_loss: 1.6531 - val_acc: 0.4220
#
# Epoch 00090: val_loss did not improve from 0.92340
# Epoch 91/100
#  - 6s - loss: 1.8399 - acc: 0.3418 - val_loss: 1.7473 - val_acc: 0.3504
#
# Epoch 00091: val_loss did not improve from 0.92340
# Epoch 92/100
#  - 6s - loss: 1.8331 - acc: 0.3383 - val_loss: 1.7600 - val_acc: 0.3578
#
# Epoch 00092: val_loss did not improve from 0.92340
# Epoch 93/100
#  - 6s - loss: 1.8569 - acc: 0.3329 - val_loss: 1.7087 - val_acc: 0.3552
#
# Epoch 00093: val_loss did not improve from 0.92340
# Epoch 94/100
#  - 6s - loss: 1.8535 - acc: 0.3359 - val_loss: 1.6732 - val_acc: 0.3568
#
# Epoch 00094: val_loss did not improve from 0.92340
# Epoch 95/100
#  - 6s - loss: 1.8598 - acc: 0.3269 - val_loss: 1.6454 - val_acc: 0.3972
#
# Epoch 00095: val_loss did not improve from 0.92340
# Epoch 96/100
#  - 6s - loss: 1.8603 - acc: 0.3260 - val_loss: 1.8273 - val_acc: 0.3836
#
# Epoch 00096: val_loss did not improve from 0.92340
# Epoch 97/100
#  - 6s - loss: 1.8771 - acc: 0.3177 - val_loss: 2.0913 - val_acc: 0.2380
#
# Epoch 00097: val_loss did not improve from 0.92340
# Epoch 98/100
#  - 6s - loss: 1.8929 - acc: 0.3120 - val_loss: 1.8115 - val_acc: 0.3288
#
# Epoch 00098: val_loss did not improve from 0.92340
# Epoch 99/100
#  - 6s - loss: 1.9023 - acc: 0.3105 - val_loss: 1.7252 - val_acc: 0.3650
#
# Epoch 00099: val_loss did not improve from 0.92340
# Epoch 100/100
#  - 6s - loss: 1.9122 - acc: 0.3008 - val_loss: 1.7392 - val_acc: 0.3636
#
# Epoch 00100: val_loss did not improve from 0.92340

# %% [markdown]
# ## 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ## 9. Calculate Classification Accuracy on Test Set

# %%
#evaluate the accuracy on test and validation set
score = model.evaluate(x_test,y_test, verbose=0)
print("\n Test Accracy :", score[1])
# Out:
#  Test Accracy : 0.6838

# %% [markdown]
# ## 10. Visualize Some Predictions
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
